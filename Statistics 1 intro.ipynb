# %% [markdown]
# # Introduction to statistics
# ### 1.) Type of statistics
#     a.) Descriptive
#     b.) Inferential
# ### 2.) Analytics Methodogy and how industry use statistics.
#     1.) Weather Forcasting
#     2.) Giving Insurance
#     3.) Stock Market
#     4.) Drug effectiveness before releasing in to the public.
#     5.) Diseased survival probability
#     6.) Election winning And exit poll prediction
#     7.) Loan approval and fraud detection
#     8.) Netflix/Amazon recommendation
#     9.) New campaign effectiveness

# %% [markdown]
# ### 3.) Population and sample

# %% [markdown]
# ### 4.) Parameter and statistics (Mean,Median and Mode)

# %%
# Mean using statistics
import statistics as st
x = [10,20,30,40,35,40,40,50,50,50,50,45,50,60,70,80]
print(st.mean(x))

# using pandas
# import pandas as pd
# x_ = pd.DataFrame(x)
# print(x_.mean())
# Out:
# 45

# %%
# Median
print(st.median(x))
# Out:
# 47.5

# %%
# mode
print(st.mode(x))
# Out:
# 50

# %% [markdown]
# ### 5.) Uses of variable : Dependent and Independent variable.

# %% [markdown]
# ### 6.) Types of variable : Continuous and Categorical Variable.

# %% [markdown]
# ![image.png](attachment:image.png)
